# %% [markdown]
# # Pegasus SAGE Fabric Setup

# %%
import sys
import os
import json
import traceback
import time
from datetime import datetime, timedelta
from dateutil import tz
from ipaddress import ip_network, ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network

# %% [markdown]
# ## Fabric Imports

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib = fablib_manager()

# %%
try:
    fablib.list_sites(
        force_refresh=True, 
        fields=[
            "name", 
            "cores_available", 
            "ram_available",
            "disk_available",
            "nic_basic_available", 
            "nic_connectx_5_available", 
            "nic_connectx_6_available",
            "nvme_available",
            "tesla_t4_available",
            "rtx6000_available",
            "a30_available",
            "a40_available",
            "fpga_u280_available"
        ]
    )
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_e3049 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_e3049 th {
#   text-align: left;
# }
# #T_e3049 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e3049 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_e3049 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e3049_row0_col0, #T_e3049_row0_col1, #T_e3049_row0_col2, #T_e3049_row0_col3, #T_e3049_row0_col4, #T_e3049_row0_col5, #T_e3049_row0_col6, #T_e3049_row0_col7, #T_e3049_row0_col8, #T_e3049_row0_col9, #T_e3049_row0_col10, #T_e3049_row0_col11, #T_e3049_row0_col12, #T_e3049_row1_col0, #T_e3049_row1_col1, #T_e3049_row1_col2, #T_e3049_row1_col3, #T_e3049_row1_col4, #T_e3049_row1_col5, #T_e3049_row1_col6, #T_e3049_row1_col7, #T_e3049_row1_col8, #T_e3049_row1_col9, #T_e3049_row1_col10, #T_e3049_row1_col11, #T_e3049_row1_col12, #T_e3049_row2_col0, #T_e3049_row2_col1, #T_e3049_row2_col2, #T_e3049_row2_col3, #T_e3049_row2_col4, #T_e3049_row2_col5, #T_e3049_row2_col6, #T_e3049_row2_col7, #T_e3049_row2_col8, #T_e3049_row2_col9, #T_e3049_row2_col10, #T_e3049_row2_col11, #T_e3049_row2_col12, #T_e3049_row3_col0, #T_e3049_row3_col1, #T_e3049_row3_col2, #T_e3049_row3_col3, #T_e3049_row3_col4, #T_e3049_row3_col5, #T_e3049_row3_col6, #T_e3049_row3_col7, #T_e3049_row3_col8, #T_e3049_row3_col9, #T_e3049_row3_col10, #T_e3049_row3_col11, #T_e3049_row3_col12, #T_e3049_row4_col0, #T_e3049_row4_col1, #T_e3049_row4_col2, #T_e3049_row4_col3, #T_e3049_row4_col4, #T_e3049_row4_col5, #T_e3049_row4_col6, #T_e3049_row4_col7, #T_e3049_row4_col8, #T_e3049_row4_col9, #T_e3049_row4_col10, #T_e3049_row4_col11, #T_e3049_row4_col12, #T_e3049_row5_col0, #T_e3049_row5_col1, #T_e3049_row5_col2, #T_e3049_row5_col3, #T_e3049_row5_col4, #T_e3049_row5_col5, #T_e3049_row5_col6, #T_e3049_row5_col7, #T_e3049_row5_col8, #T_e3049_row5_col9, #T_e3049_row5_col10, #T_e3049_row5_col11, #T_e3049_row5_col12, #T_e3049_row6_col0, #T_e3049_row6_col1, #T_e3049_row6_col2, #T_e3049_row6_col3, #T_e3049_row6_col4, #T_e3049_row6_col5, #T_e3049_row6_col6, #T_e3049_row6_col7, #T_e3049_row6_col8, #T_e3049_row6_col9, #T_e3049_row6_col10, #T_e3049_row6_col11, #T_e3049_row6_col12, #T_e3049_row7_col0, #T_e3049_row7_col1, #T_e3049_row7_col2, #T_e3049_row7_col3, #T_e3049_row7_col4, #T_e3049_row7_col5, #T_e3049_row7_col6, #T_e3049_row7_col7, #T_e3049_row7_col8, #T_e3049_row7_col9, #T_e3049_row7_col10, #T_e3049_row7_col11, #T_e3049_row7_col12, #T_e3049_row8_col0, #T_e3049_row8_col1, #T_e3049_row8_col2, #T_e3049_row8_col3, #T_e3049_row8_col4, #T_e3049_row8_col5, #T_e3049_row8_col6, #T_e3049_row8_col7, #T_e3049_row8_col8, #T_e3049_row8_col9, #T_e3049_row8_col10, #T_e3049_row8_col11, #T_e3049_row8_col12, #T_e3049_row9_col0, #T_e3049_row9_col1, #T_e3049_row9_col2, #T_e3049_row9_col3, #T_e3049_row9_col4, #T_e3049_row9_col5, #T_e3049_row9_col6, #T_e3049_row9_col7, #T_e3049_row9_col8, #T_e3049_row9_col9, #T_e3049_row9_col10, #T_e3049_row9_col11, #T_e3049_row9_col12, #T_e3049_row10_col0, #T_e3049_row10_col1, #T_e3049_row10_col2, #T_e3049_row10_col3, #T_e3049_row10_col4, #T_e3049_row10_col5, #T_e3049_row10_col6, #T_e3049_row10_col7, #T_e3049_row10_col8, #T_e3049_row10_col9, #T_e3049_row10_col10, #T_e3049_row10_col11, #T_e3049_row10_col12, #T_e3049_row11_col0, #T_e3049_row11_col1, #T_e3049_row11_col2, #T_e3049_row11_col3, #T_e3049_row11_col4, #T_e3049_row11_col5, #T_e3049_row11_col6, #T_e3049_row11_col7, #T_e3049_row11_col8, #T_e3049_row11_col9, #T_e3049_row11_col10, #T_e3049_row11_col11, #T_e3049_row11_col12, #T_e3049_row12_col0, #T_e3049_row12_col1, #T_e3049_row12_col2, #T_e3049_row12_col3, #T_e3049_row12_col4, #T_e3049_row12_col5, #T_e3049_row12_col6, #T_e3049_row12_col7, #T_e3049_row12_col8, #T_e3049_row12_col9, #T_e3049_row12_col10, #T_e3049_row12_col11, #T_e3049_row12_col12, #T_e3049_row13_col0, #T_e3049_row13_col1, #T_e3049_row13_col2, #T_e3049_row13_col3, #T_e3049_row13_col4, #T_e3049_row13_col5, #T_e3049_row13_col6, #T_e3049_row13_col7, #T_e3049_row13_col8, #T_e3049_row13_col9, #T_e3049_row13_col10, #T_e3049_row13_col11, #T_e3049_row13_col12, #T_e3049_row14_col0, #T_e3049_row14_col1, #T_e3049_row14_col2, #T_e3049_row14_col3, #T_e3049_row14_col4, #T_e3049_row14_col5, #T_e3049_row14_col6, #T_e3049_row14_col7, #T_e3049_row14_col8, #T_e3049_row14_col9, #T_e3049_row14_col10, #T_e3049_row14_col11, #T_e3049_row ...

# %% [markdown]
# ## Fabric Variables

# %%
# Create a FABlib manager
#site_names = ['INDI', 'LOSA', 'UCSD', 'GATECH', 'PSC', 'STAR', 'SALT', 'UTAH', 'MICH', 'FIU', 'GPN', 'WASH', 'RUTG', 'DALL', 'CLEM', 'AMST']
site_names = ['UCSD', 'CLEM']

# FABRIC Config
fabric_prefix =  f"pegasus-submit-sage-"
fabric_slice_name = fabric_prefix+'experiment'
fabric_os_image='default_ubuntu_20'

fabric_submit_name = fabric_prefix+'submit'
fabric_submit_site = 'LOSA'
fabric_submit_cores = 16
fabric_submit_ram = 32
fabric_submit_disk = 500
fabric_submit_ip_addr ="192.168.1.10"

worker_nodes = []
for n in site_names:
    for i in range(1,2):
        worker_nodes.append({
            "name": f"{n}-worker-{i}",
            "site": n,
            "cores": 24,
            "ram": 48,
            "disk": 500,
        })

# %% [markdown]
# ## Create Fabric Slice

# %%
try:
    #Create Slice
    fabric_slice = fablib.new_slice(name=fabric_slice_name)
    
    # Add federated learning submit node
    fabric_submit = fabric_slice.add_node(
                        name=fabric_submit_name, 
                        site=fabric_submit_site,
                        image=fabric_os_image,
                        cores=fabric_submit_cores,
                        ram=fabric_submit_ram,
                        disk=fabric_submit_disk)
    fabric_submit.add_fabnet()

    for w in worker_nodes:
        worker_node = fabric_slice.add_node(
                        name=w["name"], 
                        site=w["site"],
                        image=fabric_os_image,
                        cores=w["cores"],
                        ram=w["ram"],
                        disk=w["disk"])
        worker_node.add_fabnet()

    #Submit the Request
    fabric_slice.submit()
except Exception as e:
    print(f"Exception: {e}")
    traceback.print_exc()
# Out:
# Retry: 12, Time: 349 sec
# <style type="text/css">
# #T_9b4a0 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_9b4a0 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_9b4a0 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_9b4a0_row0_col0, #T_9b4a0_row0_col1, #T_9b4a0_row1_col0, #T_9b4a0_row1_col1, #T_9b4a0_row2_col0, #T_9b4a0_row2_col1, #T_9b4a0_row3_col0, #T_9b4a0_row3_col1, #T_9b4a0_row4_col0, #T_9b4a0_row4_col1, #T_9b4a0_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_9b4a0_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_9b4a0">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9b4a0_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_9b4a0_row0_col1" class="data row0 col1" >8bd37b04-f0d0-4451-afba-45745b2ab6c9</td>
#     </tr>
#     <tr>
#       <td id="T_9b4a0_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_9b4a0_row1_col1" class="data row1 col1" >pegasus-submit-sage-experiment</td>
#     </tr>
#     <tr>
#       <td id="T_9b4a0_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_9b4a0_row2_col1" class="data row2 col1" >2024-02-09 02:04:02 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_9b4a0_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_9b4a0_row3_col1" class="data row3 col1" >2024-02-08 02:04:02 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_9b4a0_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_9b4a0_row4_col1" class="data row4 col1" >1a0f06eb-75ea-4258-9b92-ff4d8cf999b0</td>
#     </tr>
#     <tr>
#       <td id="T_9b4a0_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_9b4a0_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6e783 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_6e783 th {
#   text-align: left;
# }
# #T_6e783 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_6e783 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_6e783 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_6e783_row0_col0, #T_6e783_row0_col1, #T_6e783_row0_col2, #T_6e783_row0_col3, #T_6e783_row0_col4, #T_6e783_row0_col5, #T_6e783_row0_col6, #T_6e783_row0_col7, #T_6e783_row0_col8, #T_6e783_row0_col9, #T_6e783_row0_col10, #T_6e783_row0_col13, #T_6e783_row0_col14, #T_6e783_row0_col15, #T_6e783_row1_col0, #T_6e783_row1_col1, #T_6e783_row1_col2, #T_6e783_row1_col3, #T_6e783_row1_col4, #T_6e783_row1_col5, #T_6e783_row1_col6, #T_6e783_row1_col7, #T_6e783_row1_col8, #T_6e783_row1_col9, #T_6e783_row1_col10, #T_6e783_row1_col13, #T_6e783_row1_col14, #T_6e783_row1_col15, #T_6e783_row2_col0, #T_6e783_row2_col1, #T_6e783_row2_col2, #T_6e783_row2_col3, #T_6e783_row2_col4, #T_6e783_row2_col5, #T_6e783_row2_col6, #T_6e783_row2_col7, #T_6e783_row2_col8, #T_6e783_row2_col9, #T_6e783_row2_col10, #T_6e783_row2_col13, #T_6e783_row2_col14, #T_6e783_row2_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_6e783_row0_col11, #T_6e783_row1_col11, #T_6e783_row2_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_6e783_row0_col12, #T_6e783_row1_col12, #T_6e783_row2_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_6e783">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_6e783_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_6e783_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_6e783_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_6e783_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_6e783_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_6e783_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_6e783_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_6e783_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_6e783_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_6e783_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_6e783_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_6e783_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_6e783_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_6e783_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_6e783_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_6e783_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6e783_row0_col0" class="data row0 col0" >ffed63a2-db50-40b8-87c3-683f5c6e9d92</td>
#       <td id="T_6e783_row0_col1" class="data row0 col1" >CLEM-worker-1</td>
#       <td id="T_6e783_row0_col2" class="data row0 col2" >24</td>
#       <td id="T_6e783_row0_col3" class="data row0 col3" >64</td>
#       <td id="T_6e783_row0_col4" class="data row0 col4" >500</td>
#       <td id="T_6e783_row0_col5" class="data row0 col5" >default_ubuntu_20</td>
#       <td id="T_6e783_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_6e783_row0_col7" class="data row0 col7" >clem-w1.fabric-testbed.net</td>
#       <td id="T_6e783_row0_col8" class="data row0 col8" >CLEM</td>
#       <td id="T_6e783_row0_col9" class="data row0 col9" >ubuntu</td>
#       <td id="T_6e783_row0_col10" class="data row0 col10" >2620:103:a006:12:f816:3eff:fe0e:2153</td>
#       <td id="T_6e783_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_6e783_row0_col12" class="data row0 col12" ></td>
#       <td id="T_6e783_row0_col13" class="data row0 col13" >ssh ${Username}@${Management IP}</td>
#       <td id="T_6e783_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/keys/fabric_sliver_key.pub</td>
#       <td id="T_6e783_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/keys/fabric_sliver_key</td>
#     </tr>
#     <tr>
#       <td id="T_6e783_row1_col0" class="data row1 col0" >f2147481-86d9-4381-9ad0-e4d853ee4eb7</td>
#       <td id="T_6e783_row1_col1" class="data row1 col1" >UCSD-worker-1</td>
#       <td id="T_6e783_row1_col2" class="data row1 col2" >24</td>
#       <td id="T_6e783_row1_col3" class="data row1 col3" >64</td>
#       <td id="T_6e783_row1_col4" class="data row1 col4" >500</td>
#       <td id="T_6e783_row1_col5" class="data row1 col5" >default_ubuntu_20</td>
#       <td id="T_6e783_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_6e783_row1_col7" class="data row1 col7" >ucsd-w5.fabric-testbed.net</td>
#       <td id="T_6e783_row1_col8" class="data row1 col8" >UCSD</td>
#       <td id="T_6e783_row1_col9" class="data row1 col9" >ubuntu</td>
#       <td id="T_6e783_row1_col10" class="data row1 col10" >132.249.252.136</td>
#       <td id="T_6e783_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_6e783_row1_col12" class="data row1 col12" ></td>
#       <td id="T_6e783_row1_col13" class="data row1 col13" >ssh ${Username}@${Management IP}</td>
#       <td id="T_6e783_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/keys/fabric_sliver_key.pub</td>
#       <td id="T_6e783_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/keys/fabric_sliver_key</td>
#     </tr>
#     <tr>
#       <td id="T_6e783_row2_col0" class="data row2 col0" >ff4f3270-0d11-4f85-9c9b-4cb7e950e14d</td>
#       <td id="T_6e783_row2_col1" class="data row2 col1" >pegasus-submit-sage-submit</td>
#       <td id="T_6e783_row2_col2" class="data row2 col2" >16</td>
#       <td id="T_6e783_row2_col3" class="data row2 col3" >32</td>
#       <td id="T_6e783_row2_col4" class="data row2 col4" >500</td>
#       <td id="T_6e783_row2_col5" class="data row2 col5" >default_ubuntu_20</td>
#       <td id="T_6e783_row2_col6" class="data row2 col6" >qcow2</td>
#       <td id="T_6e783_row2_col7" class="data row2 col7" >losa-w2.fabric-testbed.net</td>
#       <td id="T_6e783_row2_col8" class="data row2 col8" >LOSA</td>
#       <td id="T_6e783_row2_col9" class="data row2 col9" >ubuntu</td>
#       <td id="T_6e783_row2_col10" class="data row2 col10" >2001:400:a100:3070:f816:3eff:fe77:ec51</td>
#       <td id="T_6e783_row2_col11" class="data row2 col11" >Active</td>
#       <td id="T_6e783_row2_col12" class="data row2 col12" ></td>
#       <td id="T_6e783_row2_col13" class="data row2 col13" >ssh ${Username}@${Management IP}</td>
#       <td id="T_6e783_row2_col14" class="data row2 col14" >/home/fabric/work/fabric_config/keys/fabric_sliver_key.pub</td>
#       <td id="T_6e783_row2_col15" class="data row2 col15" >/home/fabric/work/fabric_config/keys/fabric_sliver_key</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_5e568 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_5e568 th {
#   text-align: left;
# }
# #T_5e568 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_5e568 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_5e568 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_5e568_row0_col0, #T_5e568_row0_col1, #T_5e568_row0_col2, #T_5e568_row0_col3, #T_5e568_row0_col4, #T_5e568_row0_col5, #T_5e568_row0_col6, #T_5e568_row1_col0, #T_5e568_row1_col1, #T_5e568_row1_col2, #T_5e568_row1_col3, #T_5e568_row1_col4, #T_5e568_row1_col5, #T_5e568_row1_col6, #T_5e568_row2_col0, #T_5e568_row2_col1, #T_5e568_row2_col2, #T_5e568_row2_col3, #T_5e568_row2_col4, #T_5e568_row2_col5, #T_5e568_row2_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_5e568_row0_col7, #T_5e568_row1_col7, #T_5e568_row2_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_5e568_row0_col8, #T_5e568_row1_col8, #T_5e568_row2_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_5e568">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_5e568_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_5e568_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_5e568_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_5e568_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_5e568_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_5e568_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_5e568_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_5e568_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_5e568_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5e568_row0_col0" class="data row0 col0" >04e631b4-fe95-4630-a540-f16126caea3f</td>
#       <td id="T_5e568_row0_col1" class="data row0 col1" >FABNET_IPv4_CLEM</td>
#       <td id="T_5e568_row0_col2" class="data row0 col2" >L3</td>
#       <td id="T_5e568_row0_col3" class="data row0 col3" >FABNetv4</td>
#       <td id="T_5e568_row0_col4" class="data row0 col4" >CLEM</td>
#       <td id="T_5e568_row0_col5" class="data row0 col5" >10.136.9.0/24</td>
#       <td id="T_5e568_row0_col6" class="data row0 col6" >10.136.9.1</td>
#       <td id="T_5e568_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_5e568_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_5e568_row1_col0" class="data row1 col0" >7847f734-5656-4c04-b27e-4d613be5d34e</td>
#       <td id="T_5e568_row1_col1" class="data row1 col1" >FABNET_IPv4_LOSA</td>
#       <td id="T_5e568_row1_col2" class="data row1 col2" >L3</td>
#       <td id="T_5e568_row1_col3" class="data row1 col3" >FABNetv4</td>
#       <td id="T_5e568_row1_col4" class="data row1 col4" >LOSA</td>
#       <td id="T_5e568_row1_col5" class="data row1 col5" >10.137.3.0/24</td>
#       <td id="T_5e568_row1_col6" class="data row1 col6" >10.137.3.1</td>
#       <td id="T_5e568_row1_col7" class="data row1 col7" >Active</td>
#       <td id="T_5e568_row1_col8" class="data row1 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_5e568_row2_col0" class="data row2 col0" >07443828-9933-42d0-b279-b74b026cd086</td>
#       <td id="T_5e568_row2_col1" class="data row2 col1" >FABNET_IPv4_UCSD</td>
#       <td id="T_5e568_row2_col2" class="data row2 col2" >L3</td>
#       <td id="T_5e568_row2_col3" class="data row2 col3" >FABNetv4</td>
#       <td id="T_5e568_row2_col4" class="data row2 col4" >UCSD</td>
#       <td id="T_5e568_row2_col5" class="data row2 col5" >10.134.134.0/24</td>
#       <td id="T_5e568_row2_col6" class="data row2 col6" >10.134.134.1</td>
#       <td id="T_5e568_row2_col7" class="data row2 col7" >Active</td>
#       <td id="T_5e568_row2_col8" class="data row2 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_53a17 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_53a17 th {
#   text-align: left;
# }
# #T_53a17 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_53a17 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_53a17 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_53a17_row0_col0, #T_53a17_row0_col1, #T_53a17_row0_col2, #T_53a17_row0_col3, #T_53a17_row0_col4, #T_53a17_row0_col5, #T_53a17_row0_col6, #T_53a17_row0_col7, #T_53a17_row0_col8, #T_53a17_row0_col9, #T_53a17_row0_col10, #T_53a17_row0_col11, #T_53a17_row1_col0, #T_53a17_row1_col1, #T_53a17_row1_col2, #T_53a17_row1_col3, #T_53a17_row1_col4, #T_53a17_row1_col5, #T_53a17_row1_col6, #T_53a17_row1_col7, #T_53a17_row1_col8, #T_53a17_row1_col9, #T_53a17_row1_col10, #T_53a17_row1_col11, #T_53a17_row2_col0, #T_53a17_row2_col1, #T_53a17_row2_col2, #T_53a17_row2_col3, #T_53a17_row2_col4, #T_53a17_row2_col5, #T_53a17_row2_col6, #T_53a17_row2_col7, #T_53a17_row2_col8, #T_53a17_row2_col9, #T_53a17_row2_col10, #T_53a17_row2_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_53a17">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_53a17_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_53a17_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_53a17_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_53a17_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_53a17_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_53a17_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_53a17_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_53a17_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_53a17_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_53a17_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_53a17_level0_col10" class="col_heading level0 col10" >IP Address</th>
#       <th id="T_53a17_level0_col11" class="col_heading level0 col11" >Numa Node</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_53a17_row0_col0" class="data row0 col0" >pegasus-submit-sage-submit-FABNET_IPv4_LOSA_nic-p1</td>
#       <td id="T_53a17_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_53a17_row0_col2" class="data row0 col2" >pegasus-submit-sage-submit</td>
#       <td id="T_53a17_row0_col3" class="data row0 col3" >FABNET_IPv4_LOSA</td>
#       <td id="T_53a17_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_53a17_row0_col5" class="data row0 col5" >auto</td>
#       <td id="T_53a17_row0_col6" class="data row0 col6" ></td>
#       <td id="T_53a17_row0_col7" class="data row0 col7" >0A:4C:01:D1:D8:41</td>
#       <td id="T_53a17_row0_col8" class="data row0 col8" >enp6s0</td>
#       <td id="T_53a17_row0_col9" class="data row0 col9" >enp6s0</td>
#       <td id="T_53a17_row0_col10" class="data row0 col10" >10.137.3.2</td>
#       <td id="T_53a17_row0_col11" class="data row0 col11" >4</td>
#     </tr>
#     <tr>
#       <td id="T_53a17_row1_col0" class="data row1 col0" >UCSD-worker-1-FABNET_IPv4_UCSD_nic-p1</td>
#       <td id="T_53a17_row1_col1" class="data row1 col1" >p1</td>
#       <td id="T_53a17_row1_col2" class="data row1 col2" >UCSD-worker-1</td>
#       <td id="T_53a17_row1_col3" class="data row1 col3" >FABNET_IPv4_UCSD</td>
#       <td id="T_53a17_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_53a17_row1_col5" class="data row1 col5" >auto</td>
#       <td id="T_53a17_row1_col6" class="data row1 col6" ></td>
#       <td id="T_53a17_row1_col7" class="data row1 col7" >02:EF:08:B0:50:5B</td>
#       <td id="T_53a17_row1_col8" class="data row1 col8" >enp6s0</td>
#       <td id="T_53a17_row1_col9" class="data row1 col9" >enp6s0</td>
#       <td id="T_53a17_row1_col10" class="data row1 col10" >10.134.134.2</td>
#       <td id="T_53a17_row1_col11" class="data row1 col11" >4</td>
#     </tr>
#     <tr>
#       <td id="T_53a17_row2_col0" class="data row2 col0" >CLEM-worker-1-FABNET_IPv4_CLEM_nic-p1</td>
#       <td id="T_53a17_row2_col1" class="data row2 col1" >p1</td>
#       <td id="T_53a17_row2_col2" class="data row2 col2" >CLEM-worker-1</td>
#       <td id="T_53a17_row2_col3" class="data row2 col3" >FABNET_IPv4_CLEM</td>
#       <td id="T_53a17_row2_col4" class="data row2 col4" >100</td>
#       <td id="T_53a17_row2_col5" class="data row2 col5" >auto</td>
#       <td id="T_53a17_row2_col6" class="data row2 col6" ></td>
#       <td id="T_53a17_row2_col7" class="data row2 col7" >06:E6:7C:D5:FB:76</td>
#       <td id="T_53a17_row2_col8" class="data row2 col8" >enp6s0</td>
#       <td id="T_53a17_row2_col9" class="data row2 col9" >enp6s0</td>
#       <td id="T_53a17_row2_col10" class="data row2 col10" >10.136.9.2</td>
#       <td id="T_53a17_row2_col11" class="data row2 col11" >6</td>
#     </tr>
#   </tbody>
# </table>
# Time to print interfaces 350 seconds

# %% [markdown]
# ## Sanity Check: Ping All Nodes From Submit

# %%
try:
    worker_ip_addresses = []
    fabric_submit = fabric_slice.get_node(name=fabric_submit_name)
    fabric_submit_addr = fabric_submit.get_interface(network_name=f'FABNET_IPv4_{fabric_submit.get_site()}').get_ip_addr()
    
    for w in worker_nodes:
        worker_node = fabric_slice.get_node(name=w["name"])
        worker_node_addr = worker_node.get_interface(network_name=f'FABNET_IPv4_{worker_node.get_site()}').get_ip_addr()
        worker_ip_addresses.append(worker_node_addr)

    for worker_node_addr in worker_ip_addresses:
        stdout, stderr = fabric_submit.execute(f'ping -c 2 {worker_node_addr}')
except Exception as e:
    print(f"Exception: {e}")
    traceback.print_exc()
# Out:
# PING 10.134.134.2 (10.134.134.2) 56(84) bytes of data.
# 64 bytes from 10.134.134.2: icmp_seq=1 ttl=62 time=3.98 ms
# 64 bytes from 10.134.134.2: icmp_seq=2 ttl=62 time=2.32 ms
#
# --- 10.134.134.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1001ms
# rtt min/avg/max/mdev = 2.319/3.151/3.984/0.832 ms
# PING 10.136.9.2 (10.136.9.2) 56(84) bytes of data.
# 64 bytes from 10.136.9.2: icmp_seq=1 ttl=59 time=80.5 ms
# 64 bytes from 10.136.9.2: icmp_seq=2 ttl=59 time=79.4 ms
#
# --- 10.136.9.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1001ms
# rtt min/avg/max/mdev = 79.350/79.911/80.473/0.561 ms

# %% [markdown]
# ## Install Software on Fabric

# %%
try:
    fabric_slice = fablib.get_slice(name=fabric_slice_name)

    for fabric_node in fabric_slice.get_nodes():
        if fabric_node.get_name() == fabric_submit_name:
            fabric_node.upload_file("fabric-submit.sh", "/home/ubuntu/setup.sh")
        else:
            fabric_node.upload_file("fabric-worker.sh", "/home/ubuntu/setup.sh")
        if type(ip_address(fabric_node.get_management_ip())) is IPv6Address:
            fabric_node.execute("sudo sed -i 's/nameserver/nameserver 2a01:4f9:c010:3f02::1\nnameserver 2a00:1098:2c::1\nnameserver 2a00:1098:2b::1\nnameserver/' /etc/resolv.conf", quiet=True)

except Exception as e:
    print(f"Exception: {e}")
    traceback.print_exc()

# %%
try:
    fabric_slice = fablib.get_slice(name=fabric_slice_name)

    fabric_submit = fabric_slice.get_node(name=fabric_submit_name)
    fabric_submit_addr = fabric_submit.get_interface(network_name=f'FABNET_IPv4_{fabric_submit.get_site()}').get_ip_addr()
    
    #Create execute threads
    execute_threads = {}
    for fabric_node in fabric_slice.get_nodes():
        os_interface = fabric_node.get_interface(network_name=f'FABNET_IPv4_{fabric_node.get_site()}').get_os_interface()
        config_command = f"sudo bash /home/ubuntu/setup.sh {os_interface} {fabric_submit_addr} {fabric_submit_name}"
        print(f"Starting config on node {fabric_node.get_name()}")
        execute_threads[fabric_node] = fabric_node.execute_thread(config_command)
        
    #Wait for results from threads
    for fabric_node,thread in execute_threads.items():
        print(f"Waiting for result from node {fabric_node.get_name()}")
        stdout,stderr = thread.result()
                        
    print("All Done!")
except Exception as e:
    print(f"Exception: {e}")
    traceback.print_exc()
# Out:
# Starting config on node pegasus-submit-sage-submit
# Starting config on node UCSD-worker-1
# Starting config on node CLEM-worker-1
# Waiting for result from node pegasus-submit-sage-submit
# Waiting for result from node UCSD-worker-1
# Waiting for result from node CLEM-worker-1
# All Done!

# %%
try:
    fabric_slice = fablib.get_slice(name=fabric_slice_name)

    fabric_submit = fabric_slice.get_node(name=fabric_submit_name)
    fabric_submit.upload_file("beehive-cloud-processing.tar.gz", "/home/ubuntu/beehive-cloud-processing.tar.gz")
    fabric_submit.execute("tar -xzvf /home/ubuntu/beehive-cloud-processing.tar.gz")
except Exception as e:
    print(f"Fail: {e}")
    traceback.print_exc()
# Out:
# beehive-cloud-processing/
# beehive-cloud-processing/workflow.py
# beehive-cloud-processing/executables/
# beehive-cloud-processing/executables/raingauge_totals.py
# beehive-cloud-processing/executables/temperature_stats.py

# %%
try:
    fabric_slice = fablib.get_slice(name=fabric_slice_name)

    fabric_submit.execute("/home/ubuntu/beehive-cloud-processing/workflow.py")
except Exception as e:
    print(f"Fail: {e}")
    traceback.print_exc()
# Out:
# [#########################] 100.0% ..Success (Unready: 0, Completed: 58, Queued: 0, Running: 0, Failed: 0)
#  2024.02.08 04:19:18.887 UTC: [ERROR]  Unable to load from directory  /home/ubuntu/inputs class java.lang.RuntimeException: Unable to connect to replica catalog implementation edu.isi.pegasus.planner.catalog.replica.impl.Directory with props {directory=/home/ubuntu/inputs}
# 2024.02.08 04:19:18.910 UTC: [WARNING]  Replica Catalog is either down or connection to it was never opened
# 2024.02.08 04:19:19.113 UTC:
# 2024.02.08 04:19:19.119 UTC:   -----------------------------------------------------------------------
# 2024.02.08 04:19:19.124 UTC:   File for submitting this DAG to HTCondor           : SageCloudWorkflow-0.dag.condor.sub
# 2024.02.08 04:19:19.129 UTC:   Log of DAGMan debugging messages                 : SageCloudWorkflow-0.dag.dagman.out
# 2024.02.08 04:19:19.134 UTC:   Log of HTCondor library output                     : SageCloudWorkflow-0.dag.lib.out
# 2024.02.08 04:19:19.139 UTC:   Log of HTCondor library error messages             : SageCloudWorkflow-0.dag.lib.err
# 2024.02.08 04:19:19.145 UTC:   Log of the life of condor_dagman itself          : SageCloudWorkflow-0.dag.dagman.log
# 2024.02.08 04:19:19.150 UTC:
# 2024.02.08 04:19:19.155 UTC:   -no_submit given, not submitting DAG to HTCondor.  You can do this with:
# 2024.02.08 04:19:19.165 UTC:   -----------------------------------------------------------------------
# 2024.02.08 04:19:19.954 UTC:   Database version: '5.0.6' (sqlite:////home/ubuntu/.pegasus/workflow.db)
# 2024.02.08 04:19:20.821 UTC:   Pegasus database was successfully created.
# 2024.02.08 04:19:20.827 UTC:   Database version: '5.0.6' (sqlite:////home/ubuntu/ubuntu/pegasus/SageCloudWorkflow/run0001/SageCloudWorkflow-0.replicas.db)
# 2024.02.08 04:19:20.851 UTC:   Output replica catalog set to jdbc:sqlite:/home/ubuntu/ubuntu/pegasus/SageCloudWorkflow/run0001/SageCloudWorkflow-0.replicas.db
# [WARNING]  Submitting to condor SageCloudWorkflow-0.dag.condor.sub
# 2024.02.08 04:19:21.374 UTC:   Time taken to execute is 2.756 seconds

# %% [markdown]
# ## Extend Fabric Slice

# %%
# Prolong Fabric Slice For 12 Days
end_date = (datetime.now(tz=tz.tzutc()) + timedelta(days=14)).strftime("%Y-%m-%d %H:%M:%S %z")
try:
    fabric_slice = fablib.get_slice(name=fabric_slice_name)
    fabric_slice = fabric_slice.renew(end_date)
    
    fabric_slice = fablib.get_slice(name=fabric_slice_name)
    print(f'New lease end time: {fabric_slice.get_lease_end()}')
except Exception as e:
    print(f"Fail: {e}")
    traceback.print_exc()

# %% [markdown]
# ## Cleanup Fabric (This Deletes The Deployment)

# %%
try:
    fabric_slice = fablib.get_slice(fabric_slice_name)
    fabric_slice.delete()
except Exception as e:
    print(f"Exception: {e}")
